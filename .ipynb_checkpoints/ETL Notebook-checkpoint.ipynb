# %%
import pandas as pd

# %%
#Loading .csv file into dataframe
shark_tank_file = 'shark_tank_data.csv'

load = pd.read_csv(shark_tank_file)
load.head()
# Out:
#    Season  Episode                     Business  \
# 0       1        1             Ava the Elephant
# 1       1        1        Mr. Tod's Pie Factory
# 2       1        1                      Wispots
# 3       1        1  College Foxes Packing Boxes
# 4       1        1                    Ionic Ear
#
#                                Description  Deal           Category  \
# 0                                      NaN     1    Health/Wellness
# 1                                      NaN     1  Food and Beverage
# 2                                      NaN     0  Business Services
# 3                                      NaN     0     Lifestyle/Home
# 4  Bluetooth device implanted into the ear     0      Software/Tech
#
#   Entrepreneur Gender State ASK_Equity  ASK_Amount  ...  Barbara Corcoran  \
# 0              Female   NaN     15.00%     50000.0  ...                 1
# 1                Male    NJ     10.00%    460000.0  ...                 1
# ...

# %%
list(load.columns)
# Out:
# ['Season',
#  'Episode',
#  'Business',
#  'Description',
#  'Deal',
#  'Category',
#  'Entrepreneur Gender',
#  'State',
#  'ASK_Equity',
#  'ASK_Amount',
#  'ASK_Valuation',
#  'DEAL_Equity',
#  'DEAL_Amount',
#  'DEAL_Valuation',
#  'Royalty',
#  'Loan',
#  'Barbara Corcoran',
#  'Mark Cuban',
#  'Lori Greiner',
#  'Robert Herjavec',
#  'Daymond John',
#  "Kevin O'Leary",
#  'Guest',
#  '# Sharks',
#  ' Investment/shark',
#  'Notes']

# %%
#Some light data cleanup
load['ASK_Equity'] = load['ASK_Equity'].replace({'%':''}, regex=True)
load['DEAL_Equity'] = load['DEAL_Equity'].replace({'%':''}, regex=True)
load.head()
# Out:
#    Season  Episode                     Business  \
# 0       1        1             Ava the Elephant
# 1       1        1        Mr. Tod's Pie Factory
# 2       1        1                      Wispots
# 3       1        1  College Foxes Packing Boxes
# 4       1        1                    Ionic Ear
#
#                                Description  Deal           Category  \
# 0                                      NaN     1    Health/Wellness
# 1                                      NaN     1  Food and Beverage
# 2                                      NaN     0  Business Services
# 3                                      NaN     0     Lifestyle/Home
# 4  Bluetooth device implanted into the ear     0      Software/Tech
#
#   Entrepreneur Gender State ASK_Equity  ASK_Amount  ...  Barbara Corcoran  \
# 0              Female   NaN      15.00     50000.0  ...                 1
# 1                Male    NJ      10.00    460000.0  ...                 1
# ...

# %%
pitch_file = 'shark_tank_pitch_detail.csv'

load2 = pd.read_csv(pitch_file)
load2.head()
# Out:
#    Season_Epi_code  Pitched_Business_Identifier  \
# 0              101             Ava the Elephant
# 1              101  College Foxes Packing Boxes
# 2              101                    Ionic Ear
# 3              101        Mr. Tod's Pie Factory
# 4              101                      Wispots
#
#                                Pitched_Business_Desc  Deal_Status Deal_Shark
# 0   (Emmy the Elephant during show, trademarked a...            1         BC
# 1  a packing and organizing service based on an a...            0        NaN
# 2  an implantable Bluetooth device requiring surg...            0        NaN
# 3                                     a pie company             1      BC+DJ
# 4  an electronic hand-held device for waiting roo...            0        NaN

# %%
#Loading raw dataframe to Postgres DB
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:ENTERPASSWORD@localhost:5432/SharkTank')
#ENTERPASSWORD
conn = engine.connect()

# %%
load.to_sql('raw_numbers', engine)
load2.to_sql('pitch_descriptions', engine)
